# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv('../raw_data/matrice_commerce_france.csv')
# Out:
# <ipython-input-12-e23750262376>:1: DtypeWarning: Columns (10,12,14,16,18,20,22,24,26,30,34,36,42,44,52,60,66,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../raw_data/matrice_commerce_france.csv')

# %%
pprint(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246521 entries, 0 to 246520
# Data columns (total 79 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Code pays déclarant   246521 non-null  int64
#  1   Pays déclarants       246521 non-null  object
#  2   Code pays partenaire  246521 non-null  int64
#  3   Pays partenaires      246521 non-null  object
#  4   Code Produit          246521 non-null  int64
#  5   Produit               246521 non-null  object
#  6   Code Élément          246521 non-null  int64
#  7   Élément               246521 non-null  object
#  8   Unité                 246521 non-null  object
#  9   Y1986                 43159 non-null   float64
#  10  Y1986F                194 non-null     object
#  11  Y1987                 45812 non-null   float64
#  12  Y1987F                208 non-null     object
#  13  Y1988                 51048 non-null   float64
# ...

# %%
df.head()
# Out:
#    Code pays déclarant Pays déclarants  Code pays partenaire Pays partenaires  \
# 0                    2     Afghanistan                    68           France
# 1                    2     Afghanistan                    68           France
# 2                    2     Afghanistan                    68           France
# 3                    2     Afghanistan                    68           France
# 4                    2     Afghanistan                    68           France
#
#    Code Produit                     Produit  Code Élément  \
# 0           868  Abats, comestibles, bovins          5610
# 1           868  Abats, comestibles, bovins          5622
# 2           526                    Abricots          5910
# 3           526                    Abricots          5922
# 4           527             Abricots séchés          5910
#
#                    Élément     Unité  Y1986  ... Y2016  Y2016F Y2017  Y2017F  \
# ...

# %%
df['Élément'].value_counts()
# Out:
# Importations - Quantité    62345
# Importations - Valeur      61907
# Exportations - Quantité    61390
# Exportations - Valeur      60879
# Name: Élément, dtype: int64

# %%
imports_qt = df[df['Élément']=='Importations - Quantité']
exports_qt = df[df['Élément']=='Exportations - Quantité']
imports_val = df[df['Élément']=='Importations - Valeur']
exports_val = df[df['Élément']=='Exportations - Valeur']

# %%
imports_qt.describe()
# Out:
#        Code pays déclarant  Code pays partenaire  Code Produit  Code Élément  \
# count         62345.000000          62345.000000  62345.000000  62345.000000
# mean            105.870639             91.753934    559.979116   5609.963285
# std              63.836849             54.719217    346.529015      0.256100
# min               1.000000              1.000000     15.000000   5607.000000
# 25%              68.000000             68.000000    250.000000   5610.000000
# 50%              68.000000             68.000000    534.000000   5610.000000
# 75%             153.000000             97.000000    837.000000   5610.000000
# max             273.000000            299.000000   1296.000000   5610.000000
#
#               Y1986         Y1987         Y1988         Y1989         Y1990  \
# count  9.178000e+03  9.986000e+03  1.117600e+04  1.152900e+04  1.091700e+04
# mean   6.127546e+03  6.460112e+03  5.459583e+03  5.734986e+03  5.760744e+03
# ...

# %%
exports_qt.describe()
# Out:
#        Code pays déclarant  Code pays partenaire  Code Produit  Code Élément  \
# count         61390.000000          61390.000000  61390.000000  61390.000000
# mean             91.750660            106.380209    573.043297   5909.958479
# std              54.387982             64.272106    350.951186      0.269393
# min               1.000000              1.000000     15.000000   5907.000000
# 25%              68.000000             68.000000    258.000000   5910.000000
# 50%              68.000000             68.000000    561.000000   5910.000000
# 75%              96.000000            153.000000    870.000000   5910.000000
# max             273.000000            299.000000   1296.000000   5910.000000
#
#               Y1986         Y1987         Y1988         Y1989         Y1990  \
# count  1.239700e+04  1.291600e+04  1.432300e+04  1.475300e+04  1.394800e+04
# mean   4.399855e+03  5.129170e+03  4.518824e+03  4.704616e+03  5.015268e+03
# ...

# %%
imports_val.describe()
# Out:
#        Code pays déclarant  Code pays partenaire  Code Produit  Code Élément  \
# count         61907.000000          61907.000000  61907.000000       61907.0
# mean            105.643998             91.823267    557.100247        5622.0
# std              63.727851             54.796273    346.143956           0.0
# min               1.000000              1.000000     15.000000        5622.0
# 25%              68.000000             68.000000    250.000000        5622.0
# 50%              68.000000             68.000000    531.000000        5622.0
# 75%             150.000000             97.000000    831.000000        5622.0
# max             273.000000            299.000000   1296.000000        5622.0
#
#                Y1986          Y1987         Y1988         Y1989         Y1990  \
# count    9183.000000    9990.000000  1.119800e+04  1.161400e+04  1.100100e+04
# mean     2991.851356    3423.853654  3.382576e+03  3.451138e+03  4.056967e+03
# ...

# %%
exports_val.describe()
# Out:
#        Code pays déclarant  Code pays partenaire  Code Produit  Code Élément  \
# count         60879.000000          60879.000000  60879.000000       60879.0
# mean             91.810657            106.181212    569.633420        5922.0
# std              54.450645             64.186482    350.500521           0.0
# min               1.000000              1.000000     15.000000        5922.0
# 25%              68.000000             68.000000    257.000000        5922.0
# 50%              68.000000             68.000000    560.000000        5922.0
# 75%              97.000000            153.000000    868.000000        5922.0
# max             273.000000            299.000000   1296.000000        5922.0
#
#                Y1986          Y1987         Y1988         Y1989         Y1990  \
# count   12401.000000   12920.000000  1.435100e+04  1.483000e+04  1.401300e+04
# mean     1885.251835    2497.943266  2.531176e+03  2.578299e+03  3.085150e+03
# ...

# %%
df.fillna(-100000, inplace=True)

# %%
years_list = [year for year in list(df.drop(columns=['Code pays déclarant','Pays déclarants', 'Pays partenaires', 'Produit', 'Élément', 'Unité','Code pays partenaire','Code Produit','Code Élément']).columns) if not year.endswith('F')]
yearsf_list = [year for year in list(df.drop(columns=['Code pays déclarant','Pays déclarants', 'Pays partenaires', 'Produit', 'Élément', 'Unité','Code pays partenaire','Code Produit','Code Élément']).columns) if year.endswith('F')]

# %%
produit = 'Abricots'
data_produit = df[df['Produit']==produit]
years_produit = data_produit[years_list]

years_produit
# Out:
#            Y1986     Y1987     Y1988     Y1989     Y1990     Y1991     Y1992  \
# 2       100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 3       100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 179     100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 180     100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 181     100000.0  100000.0  100000.0  100000.0  100000.0  100000.0       0.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 244906  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0      13.0
# 245788  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 245789  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 246154  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
# 246155  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0  100000.0
#
# ...

# %%
plt.plot(years_produit)
