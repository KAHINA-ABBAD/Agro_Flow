# %%
# %load_ext autoreload
# %autoreload 2
from projetressourcesagricoles.data import *

# %%
countrycodes = 68
elementcodes = '*'
partnercodes = [106]
itemcodes = [515]

filtered_df = get_data(countrycodes_list = countrycodes, 
         elementcodes_list = elementcodes, 
         partnercodes_list = partnercodes, 
         itemcodes_list = itemcodes)
filtered_df
# Out:
#    Code pays déclarant    Pays  Code pays partenaire Pays_partenaire  \
# 0                   68  France                    68          France
# 1                   68  France                    68          France
# 2                   68  France                    68          France
# 3                   68  France                   106          Italie
# 4                   68  France                   106          Italie
# 5                   68  France                   106          Italie
# 6                   68  France                   106          Italie
#
#    Code Produit Produit  Code Élément                  Élément   Unité  \
# 0           515  Pommes          5910  Exportations - Quantité  tonnes
# 1           515  Pommes          5922    Exportations - Valeur     US$
# 2           515  Pommes          5510               Production  tonnes
# 3           515  Pommes          5610  Importations - Quantité  tonnes
# ...
