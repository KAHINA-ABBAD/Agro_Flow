# %%
# %load_ext autoreload
# %autoreload 2
from projetressourcesagricoles.data import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_path = "/home/mickh/code/mathieudimartino/projet-ressources-agricoles/raw_data/tmp/merged.csv"
df = pd.read_csv(csv_path, low_memory=False)

# %%
add_label_columns(df)
# Out:
#        Code pays déclarant         Pays  Code pays partenaire Pays_partenaire  \
# 0                        1      Arménie                     2     Afghanistan
# 1                        1      Arménie                     2     Afghanistan
# 2                        2  Afghanistan                   202  Afrique du Sud
# 3                        2  Afghanistan                   202  Afrique du Sud
# 4                        1      Arménie                    79       Allemagne
# ...                    ...          ...                   ...             ...
# 29033                    2  Afghanistan                   150        Pays-Bas
# 29034                    2  Afghanistan                   200       Singapour
# 29035                    2  Afghanistan                   200       Singapour
# 29036                    2  Afghanistan                   211          Suisse
# 29037                    2  Afghanistan                   211          Suisse
#
#        Code Produit                  Produit  Code Élément  \
# 0               527          Abricots séchés          5610
# 1               527          Abricots séchés          5622
# 2               527          Abricots séchés          5910
# 3               527          Abricots séchés          5922
# 4               527          Abricots séchés          5610
# ...             ...                      ...           ...
# 29033           203             Pois bambara          5922
# 29034           850  Fourragers, compléments          5610
# 29035           850  Fourragers, compléments          5622
# 29036           737     Huile de citronnelle          5910
# 29037           737     Huile de citronnelle          5922
#
#                        Élément   Unité  y1961  ... y2016        y2016f y2017  \
# 0      Importations - Quantité  tonnes    NaN  ...   NaN           NaN   NaN
# 1        Importations - Valeur     US$    NaN  ...   NaN           NaN   NaN
# 2      Exportations - Quantité  tonnes    NaN  ...   NaN           NaN  24.0
# 3        Exportations - Valeur     US$    NaN  ...   NaN           NaN  28.0
# 4      Importations - Quantité  tonnes    NaN  ...   NaN           NaN   0.0
# ...                        ...     ...    ...  ...   ...           ...   ...
# 29033    Exportations - Valeur     US$    NaN  ...   NaN           NaN   NaN
# 29034  Importations - Quantité  tonnes    NaN  ...   NaN           NaN   NaN
# 29035    Importations - Valeur     US$    NaN  ...   NaN           NaN   NaN
# 29036  Exportations - Quantité  tonnes    NaN  ...   0.0  Non-officiel   NaN
# 29037    Exportations - Valeur     US$    NaN  ...   6.0  Non-officiel   NaN
#
#        y2017f y2018        y2018f y2019  y2019f  y2020             y2020f
# 0         NaN   NaN           NaN   NaN     NaN    NaN                NaN
# 1         NaN   NaN           NaN   NaN     NaN    NaN                NaN
# 2         NaN   NaN           NaN   NaN     NaN    NaN                NaN
# 3         NaN   NaN           NaN   NaN     NaN    NaN                NaN
# 4         NaN   0.0           NaN   0.0     NaN    0.0                NaN
# ...       ...   ...           ...   ...     ...    ...                ...
# 29033     NaN   0.0  Non-officiel   NaN     NaN    NaN                NaN
# 29034     NaN   NaN           NaN   NaN     NaN   42.0  Estim partenaires
# 29035     NaN   NaN           NaN   NaN     NaN  141.0  Estim partenaires
# 29036     NaN   NaN           NaN   NaN     NaN    0.0                NaN
# 29037     NaN   NaN           NaN   NaN     NaN    3.0  Estim partenaires
#
# [29038 rows x 129 columns]
