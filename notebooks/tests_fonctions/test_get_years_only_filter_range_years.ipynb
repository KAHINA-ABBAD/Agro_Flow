# %%
# %load_ext autoreload
# %autoreload 2
from projetressourcesagricoles.data import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
csv_path = "/home/mickh/code/mathieudimartino/projet-ressources-agricoles/raw_data/tmp/merged.csv"
df = pd.read_csv(csv_path, low_memory=False)

# %%
year_min = 1980
year_max = 2015

# %%
get_years(df, year_min, year_max)
# Out:
#           y1961   y1961f     y1962   y1962f     y1963   y1963f     y1964  \
# 0           NaN      NaN       NaN      NaN       NaN      NaN       NaN
# 1           NaN      NaN       NaN      NaN       NaN      NaN       NaN
# 2           NaN      NaN       NaN      NaN       NaN      NaN       NaN
# 3           NaN      NaN       NaN      NaN       NaN      NaN       NaN
# 4           NaN      NaN       NaN      NaN       NaN      NaN       NaN
# ...         ...      ...       ...      ...       ...      ...       ...
# 29067   11841.0  Agrégat   12192.0  Agrégat   17915.0  Agrégat   16371.0
# 29068   30188.0  Agrégat   19552.0  Agrégat   23726.0  Agrégat   33706.0
# 29069   83010.0  Agrégat   79368.0  Agrégat   93872.0  Agrégat  135037.0
# 29070    6000.0  Agrégat    5000.0  Agrégat    4000.0  Agrégat    3000.0
# 29071  127000.0  Agrégat  135000.0  Agrégat  162000.0  Agrégat  174000.0
#
#         y1964f     y1965   y1965f  ...     y2011   y2011f     y2012   y2012f  \
# ...

# %%
select_rangeyears(df, year_min, year_max)
# Out:
#        Code pays déclarant  Code pays partenaire  Code Produit  Code Élément  \
# 0                        1                     2           527          5610
# 1                        1                     2           527          5622
# 2                        1                     2           221          5610
# 3                        1                     2           221          5622
# 4                        1                     2           633          5610
# ...                    ...                   ...           ...           ...
# 29067                    3                     3          1726          5510
# 29068                    3                     3          1720          5510
# 29069                    3                     3          1723          5510
# 29070                    3                     3          1729          5510
# 29071                    3                     3          1735          5510
#
# ...
