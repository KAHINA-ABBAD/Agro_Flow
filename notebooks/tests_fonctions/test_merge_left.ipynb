# %%
# %load_ext autoreload
# %autoreload 2
from projetressourcesagricoles.data import get_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
countrycodes_list = 68
elementcodes_list = 5510
partnercodes_list = '*'
itemcodes_list = '*'
year_start = 2011
year_end = 2018
inner_labels = False

get_data(countrycodes_list = countrycodes_list, elementcodes_list = elementcodes_list, 
         partnercodes_list = partnercodes_list, itemcodes_list = itemcodes_list, 
         year_start = year_start, year_end = year_end, inner_labels = inner_labels)
# Out:
#      Code pays déclarant    Pays  Code pays partenaire Pays_partenaire  \
# 0                     68  France                    68          France
# 1                     68  France                    68          France
# 2                     68  France                    68          France
# 3                     68  France                    68          France
# 4                     68  France                    68          France
# ..                   ...     ...                   ...             ...
# 102                   68  France                    68          France
# 103                   68  France                    68          France
# 104                   68  France                    68          France
# 105                   68  France                    68          France
# 106                   68  France                    68          France
#
#      Code Produit                   Produit  Code Élément     Élément   Unité  \
# ...
