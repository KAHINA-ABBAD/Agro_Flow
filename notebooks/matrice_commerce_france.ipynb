# %%
import pandas as pd

# %%
matrice_france_df = pd.read_csv('../raw_data/matrice_commerce_france.csv')
# matrice_france_df.drop(columns='Unnamed: 0').to_csv('../raw_data/matrice_commerce_france2.csv', index=False)
matrice_france_df
# Out:
# /tmp/ipykernel_10305/1276006942.py:1: DtypeWarning: Columns (10,12,14,16,18,20,22,24,26,30,34,36,42,44,52,60,66,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   matrice_france_df = pd.read_csv('../raw_data/matrice_commerce_france.csv')
#         Code pays déclarant Pays déclarants  Code pays partenaire  \
# 0                         2     Afghanistan                    68
# 1                         2     Afghanistan                    68
# 2                         2     Afghanistan                    68
# 3                         2     Afghanistan                    68
# 4                         2     Afghanistan                    68
# ...                     ...             ...                   ...
# 246516                  181        Zimbabwe                    68
# 246517                  181        Zimbabwe                    68
# 246518                  181        Zimbabwe                    68
# 246519                  181        Zimbabwe                    68
# 246520                  181        Zimbabwe                    68
#
#        Pays partenaires  Code Produit                     Produit  \
# 0                France           868  Abats, comestibles, bovins
# 1                France           868  Abats, comestibles, bovins
# 2                France           526                    Abricots
# 3                France           526                    Abricots
# 4                France           527             Abricots séchés
# ...                 ...           ...                         ...
# 246516           France          1058            Viande, volaille
# 246517           France           564                         Vin
# 246518           France           564                         Vin
# 246519           France           564                         Vin
# 246520           France           564                         Vin
#
#         Code Élément                  Élément     Unité  Y1986  ... Y2016  \
# 0               5610  Importations - Quantité    tonnes    NaN  ...   NaN
# 1               5622    Importations - Valeur  1000 US$    NaN  ...   NaN
# 2               5910  Exportations - Quantité    tonnes    NaN  ...   NaN
# 3               5922    Exportations - Valeur  1000 US$    NaN  ...   NaN
# 4               5910  Exportations - Quantité    tonnes    NaN  ...   NaN
# ...              ...                      ...       ...    ...  ...   ...
# 246516          5622    Importations - Valeur  1000 US$    NaN  ...   NaN
# 246517          5610  Importations - Quantité    tonnes   18.0  ...   NaN
# 246518          5622    Importations - Valeur  1000 US$   75.0  ...   NaN
# 246519          5910  Exportations - Quantité    tonnes    NaN  ...   NaN
# 246520          5922    Exportations - Valeur  1000 US$    NaN  ...   NaN
#
#         Y2016F Y2017  Y2017F Y2018  Y2018F Y2019  Y2019F Y2020  Y2020F
# 0          NaN   NaN     NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 1          NaN   NaN     NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 2          NaN   NaN     NaN   NaN     NaN   0.0       *   1.0       *
# 3          NaN   NaN     NaN   NaN     NaN   2.0       *   2.0       *
# 4          NaN   NaN     NaN   NaN     NaN   0.0       *   NaN     NaN
# ...        ...   ...     ...   ...     ...   ...     ...   ...     ...
# 246516     NaN   NaN     NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 246517     NaN   NaN     NaN  16.0     NaN   NaN     NaN   NaN     NaN
# 246518     NaN   NaN     NaN  19.0     NaN   NaN     NaN   NaN     NaN
# 246519     NaN   NaN     NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 246520     NaN   NaN     NaN   NaN     NaN   NaN     NaN   NaN     NaN
#
# [246521 rows x 79 columns]

# %%
matrice_france_df.columns
# Out:
# Index(['Code pays déclarant', 'Pays déclarants', 'Code pays partenaire',
#        'Pays partenaires', 'Code Produit', 'Produit', 'Code Élément',
#        'Élément', 'Unité', 'Y1986', 'Y1986F', 'Y1987', 'Y1987F', 'Y1988',
#        'Y1988F', 'Y1989', 'Y1989F', 'Y1990', 'Y1990F', 'Y1991', 'Y1991F',
#        'Y1992', 'Y1992F', 'Y1993', 'Y1993F', 'Y1994', 'Y1994F', 'Y1995',
#        'Y1995F', 'Y1996', 'Y1996F', 'Y1997', 'Y1997F', 'Y1998', 'Y1998F',
#        'Y1999', 'Y1999F', 'Y2000', 'Y2000F', 'Y2001', 'Y2001F', 'Y2002',
#        'Y2002F', 'Y2003', 'Y2003F', 'Y2004', 'Y2004F', 'Y2005', 'Y2005F',
#        'Y2006', 'Y2006F', 'Y2007', 'Y2007F', 'Y2008', 'Y2008F', 'Y2009',
#        'Y2009F', 'Y2010', 'Y2010F', 'Y2011', 'Y2011F', 'Y2012', 'Y2012F',
#        'Y2013', 'Y2013F', 'Y2014', 'Y2014F', 'Y2015', 'Y2015F', 'Y2016',
#        'Y2016F', 'Y2017', 'Y2017F', 'Y2018', 'Y2018F', 'Y2019', 'Y2019F',
#        'Y2020', 'Y2020F'],
#       dtype='object')

# %% [markdown]
# ## Structure
#
# - Code pays déclarant
# - Pays déclarants
# - Code pays partenaire
# - Pays partenaires
# - Code Élément
#   - 'Importations - Quantité'
#   - 'Importations - Valeur'
#   - 'Exportation - Quantité'
#   - 'Exportation - Valeur'
# - Élément
# - Unité
# - Y__année__
# - Y__année_F__   -->> flag sur les données
